# %%
import pandas as pd
import time
import ray
from oanda_forex_utilities import *
import os
import warnings

# %%
account_details = get_oanda_account_credentials("demo_account_1.16")
account_id = account_details["account_id"]
access_token = account_details["access_token"]

print(account_id)
print(access_token)
# Out:
# 101-003-18483320-019
# 87a216bb7b0e640e4af97a43499b58b9-4803472d0b66dd35b5d7541f3105caf5

# %%
ray.init()
@ray.remote
def automated_trade(currency_pair):
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')   
        get_extraction_time("M5")
        time.sleep(1.5)
        state = True
        complete_list = []
        trigger_bar ={}
        while state == True:
            df = get_candle_data(account_id, access_token, currency_pair, "M5", 500)
            df_longer_time = get_candle_data(account_id, access_token, currency_pair, "M30", 500)

            df_with_indicators = get_macd_indicator(df)
            df_with_indicators = get_adx_indicator(df_with_indicators)
            df_longer_time_with_indicators = get_ema_indicator(df_with_indicators, window = 8)
            df_longer_time_with_indicators = get_ema_indicator(df_with_indicators, window = 13)
            df_longer_time_with_indicators = get_ema_indicator(df_with_indicators, window = 21)
            df_with_indicators_complete = df_with_indicators[df_with_indicators["complete"] == True]

            df_longer_time_with_indicators = get_ema_indicator(df_longer_time, window = 8)
            df_longer_time_with_indicators = get_ema_indicator(df_longer_time_with_indicators, window = 13)
            df_longer_time_with_indicators = get_ema_indicator(df_longer_time_with_indicators, window = 21)

            if df_with_indicators_complete["time"].iloc[-1] not in complete_list:
                complete_list.append(df_with_indicators_complete["time"].iloc[-1])

                if len(trigger_bar) == 0:
                    if (
                            (df_with_indicators_complete["price_high"].iloc[-1] >= df_with_indicators_complete["ema_8"].iloc[-1]) and
                            (df_with_indicators_complete["price_close"].iloc[-1] < df_with_indicators_complete["ema_21"].iloc[-1]) and

                            (df_with_indicators_complete["price_high"].iloc[-2] < df_with_indicators_complete["ema_8"].iloc[-2]) and
                            (df_with_indicators_complete["price_high"].iloc[-3] < df_with_indicators_complete["ema_8"].iloc[-3]) and
                            (df_with_indicators_complete["price_high"].iloc[-4] < df_with_indicators_complete["ema_8"].iloc[-4]) and
    #                         (df_with_indicators_complete["price_high"].iloc[-5] < df_with_indicators_complete["ema_8"].iloc[-5]) and

                            (df_longer_time_with_indicators["price_high"].iloc[-1] < df_longer_time_with_indicators["ema_8"].iloc[-1]) and
                            (df_longer_time_with_indicators["price_high"].iloc[-2] < df_longer_time_with_indicators["ema_8"].iloc[-2])


                        ):
                        trigger_price = min(df_with_indicators_complete["price_close"].iloc[-1],
                                            df_with_indicators_complete["price_close"].iloc[-2],
                                            df_with_indicators_complete["price_close"].iloc[-3],
                                            df_with_indicators_complete["price_close"].iloc[-4],
                                            df_with_indicators_complete["price_close"].iloc[-5])
                        trigger_bar = {"SELL": trigger_price}
                        print(df_with_indicators_complete["time"].iloc[-1], currency_pair, " TRIGGER BAR - SELL")

                    elif(
                            (df_with_indicators_complete["price_low"].iloc[-1] <= df_with_indicators_complete["ema_8"].iloc[-1]) and
                            (df_with_indicators_complete["price_close"].iloc[-1] > df_with_indicators_complete["ema_21"].iloc[-1]) and

                            (df_with_indicators_complete["price_low"].iloc[-2] > df_with_indicators_complete["ema_8"].iloc[-2]) and
                            (df_with_indicators_complete["price_low"].iloc[-3] > df_with_indicators_complete["ema_8"].iloc[-3]) and
                            (df_with_indicators_complete["price_low"].iloc[-4] > df_with_indicators_complete["ema_8"].iloc[-4]) and
    #                         (df_with_indicators_complete["price_low"].iloc[-5] > df_with_indicators_complete["ema_8"].iloc[-5]) and

                            (df_longer_time_with_indicators["price_low"].iloc[-1] > df_longer_time_with_indicators["ema_8"].iloc[-1]) and
                            (df_longer_time_with_indicators["price_low"].iloc[-2] > df_longer_time_with_indicators["ema_8"].iloc[-2])
                        ):
                        trigger_price = max(df_with_indicators_complete["price_close"].iloc[-1],
                                            df_with_indicators_complete["price_close"].iloc[-2],
                                            df_with_indicators_complete["price_close"].iloc[-3],
                                            df_with_indicators_complete["price_close"].iloc[-4],
                                            df_with_indicators_complete["price_close"].iloc[-5])
                        trigger_bar = {"BUY": trigger_price}
                        print(df_with_indicators_complete["time"].iloc[-1], currency_pair, " TRIGGER BAR - BUY")

                    else:
                        print(df_with_indicators_complete["time"].iloc[-1], currency_pair, " NOTHING HAPPENS")
                        trigger_bar = {}

                else:
                    print("STATUS: 1 TRIGGER BAR")
                    if (
                            (list(trigger_bar.keys())[0] == "SELL") &
                            (df_with_indicators_complete["price_low"] <= trigger_bar['SELL'])
                       ):
                        print(df_with_indicators_complete["time"].iloc[-1], currency_pair, " SELL ORDER FILLED")
                        if currency_pair in ["EUR_JPY", "AUD_JPY", "NZD_JPY", "USD_JPY", "GBP_JPY"]:
                            stop_loss = 1000
                        else:
                            stop_loss = 10
                        create_market_order_with_sl_tp(account_id, access_token, currency_pair, "SELL", 5000,
                                              round(float(df_with_indicators_complete["price_close"].iloc[-1]) + stop_loss/10000,5),
                                              round(float(df_with_indicators_complete["price_close"].iloc[-1]) - stop_loss/10000,5))
                        trigger_bar = {}

                    elif (

                        (list(trigger_bar.keys())[0] == "BUY") &
                        (df_with_indicators_complete["price_high"] >= trigger_bar['BUY'])
                    ):
                        print(df_with_indicators_complete["time"].iloc[-1], currency_pair, " BUY ORDER FILLED")
                        os.system( "say buy trade executed" )
                        if currency_pair in ["EUR_JPY", "AUD_JPY", "NZD_JPY", "USD_JPY", "GBP_JPY"]:
                            stop_loss = 1000
                        else:
                            stop_loss = 10
                        create_market_order_with_sl_tp(account_id, access_token, currency_pair, "BUY", 5000,
                                              round(float(df_with_indicators_complete["price_close"].iloc[-1]) - stop_loss/10000,5),
                                              round(float(df_with_indicators_complete["price_close"].iloc[-1]) + stop_loss/10000,5))
                        trigger_bar = {}

                    else:
                        print(df_with_indicators_complete["time"].iloc[-1], currency_pair, " NOTHING HAPPENS")

            time.sleep(10)
# Out:
# 2021-08-03 15:22:52,275	INFO services.py:1245 -- View the Ray dashboard at http://127.0.0.1:8265

# %%
for i in range(1, 10):
    try:
        ray.get([automated_trade.remote("EUR_USD"), automated_trade.remote("USD_JPY"),
                 automated_trade.remote("USD_CHF"), automated_trade.remote("GBP_USD"),
                 automated_trade.remote("GBP_CHF"), automated_trade.remote("GBP_JPY"),
                 automated_trade.remote("AUD_USD"), automated_trade.remote("EUR_GBP")])
    except Exception as e:
        print (e)
        print ('Restarting!')
        ray.shutdown()
        continue
    else:
        break
# Out:
# (pid=48796) 2021-08-03 07:20:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48792) 2021-08-03 07:20:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48795) 2021-08-03 07:20:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48799) 2021-08-03 07:20:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48798) 2021-08-03 07:20:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48793) 2021-08-03 07:20:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48797) 2021-08-03 07:20:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48794) 2021-08-03 07:20:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48792) 2021-08-03 07:25:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48793) 2021-08-03 07:25:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48794) 2021-08-03 07:25:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48798) 2021-08-03 07:25:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48795) 2021-08-03 07:25:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48797) 2021-08-03 07:25:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48799) 2021-08-03 07:25:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48796) 2021-08-03 07:25:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48794) 2021-08-03 07:30:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48798) 2021-08-03 07:30:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48793) 2021-08-03 07:30:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48797) 2021-08-03 07:30:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48799) 2021-08-03 07:30:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48795) 2021-08-03 07:30:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48792) 2021-08-03 07:30:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48796) 2021-08-03 07:30:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48793) 2021-08-03 07:35:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48797) 2021-08-03 07:35:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48794) 2021-08-03 07:35:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48799) 2021-08-03 07:35:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48795) 2021-08-03 07:35:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48792) 2021-08-03 07:35:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48796) 2021-08-03 07:35:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48798) 2021-08-03 07:35:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48794) 2021-08-03 07:40:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48799) 2021-08-03 07:40:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48793) 2021-08-03 07:40:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48797) 2021-08-03 07:40:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48798) 2021-08-03 07:40:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48795) 2021-08-03 07:40:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48796) 2021-08-03 07:40:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48792) 2021-08-03 07:40:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48792) 2021-08-03 07:45:00+00:00 AUD_USD  TRIGGER BAR - BUY
# (pid=48794) 2021-08-03 07:45:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48796) 2021-08-03 07:45:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48797) 2021-08-03 07:45:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48799) 2021-08-03 07:45:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48793) 2021-08-03 07:45:00+00:00 EUR_GBP  TRIGGER BAR - SELL
# (pid=48795) 2021-08-03 07:45:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48798) 2021-08-03 07:45:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48794) 2021-08-03 07:50:00+00:00 GBP_JPY  NOTHING HAPPENS
# ray::automated_trade() (pid=48793, ip=172.16.7.128)
#   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
#   File "/opt/anaconda3/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 330, in _function_with_tracing
#     return function(*args, **kwargs)
#   File "<ipython-input-8-e0d37eeaab80>", line 77, in automated_trade
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1329, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# Restarting!
# 2021-08-03 15:55:06,423	INFO services.py:1245 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=48909) 2021-08-03 07:55:00+00:00 EUR_USD  TRIGGER BAR - BUY
# (pid=48914) 2021-08-03 07:55:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48912) 2021-08-03 07:55:00+00:00 GBP_USD  TRIGGER BAR - BUY
# (pid=48916) 2021-08-03 07:50:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48913) 2021-08-03 07:55:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48915) 2021-08-03 07:55:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48917) 2021-08-03 07:50:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48911) 2021-08-03 07:55:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48916) 2021-08-03 07:55:00+00:00 USD_CHF  TRIGGER BAR - SELL
# (pid=48917) 2021-08-03 07:55:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48917) 2021-08-03 08:00:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48915) 2021-08-03 08:00:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48914) 2021-08-03 08:00:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48913) 2021-08-03 08:00:00+00:00 GBP_CHF  NOTHING HAPPENS
# ray::automated_trade() (pid=48909, ip=172.16.7.128)
#   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
#   File "/opt/anaconda3/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 330, in _function_with_tracing
#     return function(*args, **kwargs)
#   File "<ipython-input-8-e0d37eeaab80>", line 79, in automated_trade
# KeyError: 'SELL'
# Restarting!
# 2021-08-03 16:05:10,235	INFO services.py:1245 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=48966) 2021-08-03 08:05:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48970) 2021-08-03 08:05:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48974) 2021-08-03 08:05:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48968) 2021-08-03 08:05:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48973) 2021-08-03 08:05:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48972) 2021-08-03 08:00:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48969) 2021-08-03 08:05:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48971) 2021-08-03 08:05:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48972) 2021-08-03 08:05:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48969) 2021-08-03 08:10:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48970) 2021-08-03 08:10:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48966) 2021-08-03 08:10:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48973) 2021-08-03 08:10:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48974) 2021-08-03 08:10:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48972) 2021-08-03 08:10:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48971) 2021-08-03 08:10:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=48968) 2021-08-03 08:10:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48974) 2021-08-03 08:15:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48968) 2021-08-03 08:15:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=48972) 2021-08-03 08:15:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=48969) 2021-08-03 08:15:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=48971) 2021-08-03 08:15:00+00:00 EUR_GBP  TRIGGER BAR - SELL
# (pid=48966) 2021-08-03 08:15:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=48970) 2021-08-03 08:15:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48973) 2021-08-03 08:15:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=48970) 2021-08-03 08:20:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=48974) 2021-08-03 08:20:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=48972) 2021-08-03 08:20:00+00:00 AUD_USD  NOTHING HAPPENS
# ray::automated_trade() (pid=48971, ip=172.16.7.128)
#   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
#   File "/opt/anaconda3/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 330, in _function_with_tracing
#     return function(*args, **kwargs)
#   File "<ipython-input-8-e0d37eeaab80>", line 77, in automated_trade
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1329, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# Restarting!
# 2021-08-03 16:25:15,514	INFO services.py:1245 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=49019) 2021-08-03 08:25:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49017) 2021-08-03 08:25:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49022) 2021-08-03 08:25:00+00:00 USD_JPY  TRIGGER BAR - BUY
# (pid=49025) 2021-08-03 08:25:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49024) 2021-08-03 08:20:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49021) 2021-08-03 08:25:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49023) 2021-08-03 08:25:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49020) 2021-08-03 08:20:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49020) 2021-08-03 08:25:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49024) 2021-08-03 08:25:00+00:00 USD_CHF  NOTHING HAPPENS
# ray::automated_trade() (pid=49022, ip=172.16.7.128)
#   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
#   File "/opt/anaconda3/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 330, in _function_with_tracing
#     return function(*args, **kwargs)
#   File "<ipython-input-8-e0d37eeaab80>", line 79, in automated_trade
# KeyError: 'SELL'
# Restarting!
# 2021-08-03 16:35:05,022	INFO services.py:1245 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=49074) 2021-08-03 08:30:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49077) 2021-08-03 08:30:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49080) 2021-08-03 08:35:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49081) 2021-08-03 08:30:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49079) 2021-08-03 08:35:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49082) 2021-08-03 08:35:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49076) 2021-08-03 08:35:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49078) 2021-08-03 08:35:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49077) 2021-08-03 08:35:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49081) 2021-08-03 08:35:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49074) 2021-08-03 08:35:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49082) 2021-08-03 08:40:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49076) 2021-08-03 08:40:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49080) 2021-08-03 08:40:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49078) 2021-08-03 08:40:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49074) 2021-08-03 08:40:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49081) 2021-08-03 08:40:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49079) 2021-08-03 08:40:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49077) 2021-08-03 08:40:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49074) 2021-08-03 08:45:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49079) 2021-08-03 08:45:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49076) 2021-08-03 08:45:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49081) 2021-08-03 08:45:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49077) 2021-08-03 08:45:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49080) 2021-08-03 08:45:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49082) 2021-08-03 08:45:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49078) 2021-08-03 08:45:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49074) 2021-08-03 08:50:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49080) 2021-08-03 08:50:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49081) 2021-08-03 08:50:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49079) 2021-08-03 08:50:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49077) 2021-08-03 08:50:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49076) 2021-08-03 08:50:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49082) 2021-08-03 08:50:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49078) 2021-08-03 08:50:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49082) 2021-08-03 08:55:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49076) 2021-08-03 08:55:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49078) 2021-08-03 08:55:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49079) 2021-08-03 08:55:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49080) 2021-08-03 08:55:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49081) 2021-08-03 08:55:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49074) 2021-08-03 08:55:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49077) 2021-08-03 08:55:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49082) 2021-08-03 09:00:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49078) 2021-08-03 09:00:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49077) 2021-08-03 09:00:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49080) 2021-08-03 09:00:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49074) 2021-08-03 09:00:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49081) 2021-08-03 09:00:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49076) 2021-08-03 09:00:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49079) 2021-08-03 09:00:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49078) 2021-08-03 09:05:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49080) 2021-08-03 09:05:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49077) 2021-08-03 09:05:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49081) 2021-08-03 09:05:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49074) 2021-08-03 09:05:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49076) 2021-08-03 09:05:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49079) 2021-08-03 09:05:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49082) 2021-08-03 09:05:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49079) 2021-08-03 09:10:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49082) 2021-08-03 09:10:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49076) 2021-08-03 09:10:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49078) 2021-08-03 09:10:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49080) 2021-08-03 09:10:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49074) 2021-08-03 09:10:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49077) 2021-08-03 09:10:00+00:00 USD_CHF  TRIGGER BAR - SELL
# (pid=49081) 2021-08-03 09:10:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49082) 2021-08-03 09:15:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49079) 2021-08-03 09:15:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49078) 2021-08-03 09:15:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49081) 2021-08-03 09:15:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49074) 2021-08-03 09:15:00+00:00 EUR_USD  NOTHING HAPPENS
# ray::automated_trade() (pid=49077, ip=172.16.7.128)
#   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
#   File "/opt/anaconda3/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 330, in _function_with_tracing
#     return function(*args, **kwargs)
#   File "<ipython-input-8-e0d37eeaab80>", line 77, in automated_trade
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1329, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# Restarting!
# 2021-08-03 17:20:14,511	INFO services.py:1245 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=49222) 2021-08-03 09:20:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49220) 2021-08-03 09:20:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49217) 2021-08-03 09:15:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49221) 2021-08-03 09:20:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49218) 2021-08-03 09:15:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49219) 2021-08-03 09:20:00+00:00 AUD_USD  NOTHING HAPPENS
# (pid=49216) 2021-08-03 09:20:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49214) 2021-08-03 09:20:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49217) 2021-08-03 09:20:00+00:00 USD_JPY  NOTHING HAPPENS
# (pid=49218) 2021-08-03 09:20:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49214) 2021-08-03 09:25:00+00:00 EUR_USD  NOTHING HAPPENS
# (pid=49220) 2021-08-03 09:25:00+00:00 EUR_GBP  NOTHING HAPPENS
# (pid=49218) 2021-08-03 09:25:00+00:00 GBP_USD  NOTHING HAPPENS
# (pid=49222) 2021-08-03 09:25:00+00:00 GBP_JPY  NOTHING HAPPENS
# (pid=49219) 2021-08-03 09:25:00+00:00 AUD_USD  TRIGGER BAR - SELL
# (pid=49216) 2021-08-03 09:25:00+00:00 GBP_CHF  NOTHING HAPPENS
# (pid=49221) 2021-08-03 09:25:00+00:00 USD_CHF  NOTHING HAPPENS
# (pid=49217) 2021-08-03 09:25:00+00:00 USD_JPY  NOTHING HAPPENS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-371f2d3dfa3f> in <module>
#       1 for i in range(1, 10):
#       2     try:
# ----> 3         ray.get([automated_trade.remote("EUR_USD"), automated_trade.remote("USD_JPY"),
#       4                  automated_trade.remote("USD_CHF"), automated_trade.remote("GBP_USD"),
#       5                  automated_trade.remote("GBP_CHF"), automated_trade.remote("GBP_JPY"),
#
# /opt/anaconda3/lib/python3.8/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#      80         if client_mode_should_convert():
#      81             return getattr(ray, func.__name__)(*args, **kwargs)
# ---> 82         return func(*args, **kwargs)
#      83
#      84     return wrapper
#
# /opt/anaconda3/lib/python3.8/site-packages/ray/worker.py in get(object_refs, timeout)
#    1555
#    1556         # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 1557         values, debugger_breakpoint = worker.get_objects(
#    1558             object_refs, timeout=timeout)
#    1559         for i, value in enumerate(values):
#
# /opt/anaconda3/lib/python3.8/site-packages/ray/worker.py in get_objects(self, object_refs, timeout)
#     338
#     339         timeout_ms = int(timeout * 1000) if timeout else -1
# --> 340         data_metadata_pairs = self.core_worker.get_objects(
#     341             object_refs, self.current_task_id, timeout_ms)
#     342         debugger_breakpoint = b""
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.get_objects()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
ray.shutdown()
